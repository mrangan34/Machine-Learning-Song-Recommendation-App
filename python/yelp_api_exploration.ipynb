# %%
# import dependencies
import requests
import pandas as pd
import json

# %%
yelp_base = 'https://api.yelp.com/v3/businesses/search?'
yellow = {'Authorization': 'bearer R6CwwairRA626hrSHNGnk5-RH1orXLW4KSCj6z2CKl24Y16zwhiD-FszQ9xefF3cWWJLsur9cRF6gf8aG7r7XigoBAet-YGqYAFmb9dlPie52Yo9E3aDMQOoeuZ_X3Yx'}
# Dummy Call to retrieve total amount
r = requests.get(yelp_base + 'location=philadelphia&price=3,4&limit=50&offset=2', headers=yellow)
response_json = json.loads(r.content)

# %%
response_json
# Out:
# {'businesses': [{'id': '2CDI713ATuxHfnB5b-sBdw',
#    'alias': 'vedge-philadelphia',
#    'name': 'Vedge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zRDzsJebicuMt8_rKaJDqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vedge-philadelphia?adjust_creative=FYDP6p5G9ZcI4UW7inh88A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=FYDP6p5G9ZcI4UW7inh88A',
#    'review_count': 1388,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9479310476302,
#     'longitude': -75.1614279836694},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '1221 Locust St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1221 Locust St', 'Philadelphia, PA 19107']},
# ...

# %%
for i in range(len(response_json['businesses'])):
    print(response_json['businesses'][i]['name'])
# Out:
# Vedge
# Parc
# Morimoto
# Amada
# Vernick Food & Drink
# Butcher and Singer
# Alma de Cuba
# Fogo de Chão Brazilian Steakhouse
# Buddakan
# Abe Fisher
# Barclay Prime
# Bistrot La Minette
# Vetri Cucina
# Tinto
# The Franklin Mortgage & Investment Company
# Little Fish
# Bibou
# Lacroix Restaurant at The Rittenhouse
# Wm Mulherin's Sons
# Noord
# Estia
# Del Frisco's Double Eagle Steakhouse
# Osteria
# The Capital Grille
# Tequilas Restaurant
# Fond
# The Love
# Devon Seafood Grill
# Entree BYOB
# Friday Saturday Sunday
# Davios
# The Ranstead Room
# Serpico
# Laurel
# Mercato BYOB
# Urban Farmer Philadelphia
# Perla
# Spice Finch
# Pumpkin
# Ocean Prime
# Townsend
# Jaxon BYOB
# Fork
# Zama
# Helm
# Chima Steakhouse
# Moshulu
# Kalaya Thai Kitchen
# Rouge
# Melograno

# %%
response_json['businesses'][0]
# Out:
# {'id': '2CDI713ATuxHfnB5b-sBdw',
#  'alias': 'vedge-philadelphia',
#  'name': 'Vedge',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zRDzsJebicuMt8_rKaJDqw/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/vedge-philadelphia?adjust_creative=FYDP6p5G9ZcI4UW7inh88A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=FYDP6p5G9ZcI4UW7inh88A',
#  'review_count': 1388,
#  'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#   {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 39.9479310476302, 'longitude': -75.1614279836694},
#  'transactions': ['delivery'],
#  'price': '$$$',
#  'location': {'address1': '1221 Locust St',
#   'address2': '',
#   'address3': '',
#   'city': 'Philadelphia',
#   'zip_code': '19107',
#   'country': 'US',
#   'state': 'PA',
#   'display_address': ['1221 Locust St', 'Philadelphia, PA 19107']},
#  'phone': '+12153207500',
#  'display_phone': '(215) 320-7500',
# ...
